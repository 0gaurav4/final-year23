# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("laptop_price.csv", encoding='latin-1')
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %% [markdown]
# ## Cleaning Data-

# %%
df.drop(columns='laptop_ID',inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60

# %%
df["Company"]
# Out:
# 0        Apple
# 1        Apple
# 2           HP
# 3        Apple
# 4        Apple
#          ...
# 1298    Lenovo
# 1299    Lenovo
# 1300    Lenovo
# 1301        HP
# 1302      Asus
# Name: Company, Length: 1303, dtype: object

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS   1.37      1339.69
# 1        Intel HD Graphics 6000  macOS   1.34       898.94
# 2         Intel HD Graphics 620  No OS   1.86       575.00
# 3            AMD Radeon Pro 455  macOS   1.83      2537.45
# 4  Intel Iris Plus Graphics 650  macOS   1.37      1803.60

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price_euros       1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(8)
# memory usage: 112.1+ KB

# %%
df['Price_euros'] = df['Price_euros']*81
df.rename({'Price_euros': 'Price'},axis=1,inplace=True)

# %%
df['Cpu_Name'] = df['Cpu'].apply(lambda x:x.split()[0])
df['Cpu_model'] = df['Cpu'].apply(lambda x:' '.join(x.split()[1:3]))
df['Cpu_Speed'] = df['Cpu'].apply(lambda x:x.split()[-1])
df['Cpu_Speed'] = df['Cpu_Speed'].str.replace('GHz','')
df.drop(columns='Cpu',inplace=True)
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...                                          ...  ...                  ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080    4            128GB SSD
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800   16            512GB SSD
# 1300                                    1366x768    2   64GB Flash Storage
# 1301                                    1366x768    6              1TB HDD
# 1302                                    1366x768    4            500GB HDD
#
#                                Gpu       OpSys  Weight      Price Cpu_Name  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37  108514.89    Intel
# 1           Intel HD Graphics 6000       macOS    1.34   72814.14    Intel
# 2            Intel HD Graphics 620       No OS    1.86   46575.00    Intel
# 3               AMD Radeon Pro 455       macOS    1.83  205533.45    Intel
# 4     Intel Iris Plus Graphics 650       macOS    1.37  146091.60    Intel
# ...                            ...         ...     ...        ...      ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   51678.00    Intel
# 1299         Intel HD Graphics 520  Windows 10    1.30  121419.00    Intel
# 1300             Intel HD Graphics  Windows 10    1.50   18549.00    Intel
# 1301            AMD Radeon R5 M330  Windows 10    2.19   61884.00    Intel
# 1302             Intel HD Graphics  Windows 10    2.20   29889.00    Intel
#
#          Cpu_model Cpu_Speed
# 0          Core i5       2.3
# 1          Core i5       1.8
# 2          Core i5       2.5
# 3          Core i7       2.7
# 4          Core i5       3.1
# ...            ...       ...
# 1298       Core i7       2.5
# 1299       Core i7       2.5
# 1300  Celeron Dual       1.6
# 1301       Core i7       2.5
# 1302  Celeron Dual       1.6
#
# [1303 rows x 14 columns]

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...                                          ...  ...                  ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080    4            128GB SSD
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800   16            512GB SSD
# 1300                                    1366x768    2   64GB Flash Storage
# 1301                                    1366x768    6              1TB HDD
# 1302                                    1366x768    4            500GB HDD
#
#                                Gpu       OpSys  Weight      Price Cpu_Name  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37  108514.89    Intel
# 1           Intel HD Graphics 6000       macOS    1.34   72814.14    Intel
# 2            Intel HD Graphics 620       No OS    1.86   46575.00    Intel
# 3               AMD Radeon Pro 455       macOS    1.83  205533.45    Intel
# 4     Intel Iris Plus Graphics 650       macOS    1.37  146091.60    Intel
# ...                            ...         ...     ...        ...      ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   51678.00    Intel
# 1299         Intel HD Graphics 520  Windows 10    1.30  121419.00    Intel
# 1300             Intel HD Graphics  Windows 10    1.50   18549.00    Intel
# 1301            AMD Radeon R5 M330  Windows 10    2.19   61884.00    Intel
# 1302             Intel HD Graphics  Windows 10    2.20   29889.00    Intel
#
#          Cpu_model Cpu_Speed  Touchscreen  IPS
# 0          Core i5       2.3            0    1
# 1          Core i5       1.8            0    0
# 2          Core i5       2.5            0    0
# 3          Core i7       2.7            0    1
# 4          Core i5       3.1            0    1
# ...            ...       ...          ...  ...
# 1298       Core i7       2.5            1    1
# 1299       Core i7       2.5            1    1
# 1300  Celeron Dual       1.6            0    0
# 1301       Core i7       2.5            0    0
# 1302  Celeron Dual       1.6            0    0
#
# [1303 rows x 16 columns]

# %%
df['Resolution'] = df['ScreenResolution'].apply(lambda x:x.split()[-1])
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...                                          ...  ...                  ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080    4            128GB SSD
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800   16            512GB SSD
# 1300                                    1366x768    2   64GB Flash Storage
# 1301                                    1366x768    6              1TB HDD
# 1302                                    1366x768    4            500GB HDD
#
#                                Gpu       OpSys  Weight      Price Cpu_Name  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37  108514.89    Intel
# 1           Intel HD Graphics 6000       macOS    1.34   72814.14    Intel
# 2            Intel HD Graphics 620       No OS    1.86   46575.00    Intel
# 3               AMD Radeon Pro 455       macOS    1.83  205533.45    Intel
# 4     Intel Iris Plus Graphics 650       macOS    1.37  146091.60    Intel
# ...                            ...         ...     ...        ...      ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   51678.00    Intel
# 1299         Intel HD Graphics 520  Windows 10    1.30  121419.00    Intel
# 1300             Intel HD Graphics  Windows 10    1.50   18549.00    Intel
# 1301            AMD Radeon R5 M330  Windows 10    2.19   61884.00    Intel
# 1302             Intel HD Graphics  Windows 10    2.20   29889.00    Intel
#
#          Cpu_model Cpu_Speed  Touchscreen  IPS Resolution
# 0          Core i5       2.3            0    1  2560x1600
# 1          Core i5       1.8            0    0   1440x900
# 2          Core i5       2.5            0    0  1920x1080
# 3          Core i7       2.7            0    1  2880x1800
# 4          Core i5       3.1            0    1  2560x1600
# ...            ...       ...          ...  ...        ...
# 1298       Core i7       2.5            1    1  1920x1080
# 1299       Core i7       2.5            1    1  3200x1800
# 1300  Celeron Dual       1.6            0    0   1366x768
# 1301       Core i7       2.5            0    0   1366x768
# 1302  Celeron Dual       1.6            0    0   1366x768
#
# [1303 rows x 17 columns]

# %%
df.drop(columns='ScreenResolution',inplace=True)
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#       Ram               Memory                           Gpu       OpSys  \
# 0       8            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1       8  128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2       8            256GB SSD         Intel HD Graphics 620       No OS
# 3      16            512GB SSD            AMD Radeon Pro 455       macOS
# 4       8            256GB SSD  Intel Iris Plus Graphics 650       macOS
# ...   ...                  ...                           ...         ...
# 1298    4            128GB SSD         Intel HD Graphics 520  Windows 10
# 1299   16            512GB SSD         Intel HD Graphics 520  Windows 10
# 1300    2   64GB Flash Storage             Intel HD Graphics  Windows 10
# 1301    6              1TB HDD            AMD Radeon R5 M330  Windows 10
# 1302    4            500GB HDD             Intel HD Graphics  Windows 10
#
#       Weight      Price Cpu_Name     Cpu_model Cpu_Speed  Touchscreen  IPS  \
# 0       1.37  108514.89    Intel       Core i5       2.3            0    1
# 1       1.34   72814.14    Intel       Core i5       1.8            0    0
# 2       1.86   46575.00    Intel       Core i5       2.5            0    0
# 3       1.83  205533.45    Intel       Core i7       2.7            0    1
# 4       1.37  146091.60    Intel       Core i5       3.1            0    1
# ...      ...        ...      ...           ...       ...          ...  ...
# 1298    1.80   51678.00    Intel       Core i7       2.5            1    1
# 1299    1.30  121419.00    Intel       Core i7       2.5            1    1
# 1300    1.50   18549.00    Intel  Celeron Dual       1.6            0    0
# 1301    2.19   61884.00    Intel       Core i7       2.5            0    0
# 1302    2.20   29889.00    Intel  Celeron Dual       1.6            0    0
#
#      Resolution
# 0     2560x1600
# 1      1440x900
# 2     1920x1080
# 3     2880x1800
# 4     2560x1600
# ...         ...
# 1298  1920x1080
# 1299  3200x1800
# 1300   1366x768
# 1301   1366x768
# 1302   1366x768
#
# [1303 rows x 16 columns]

# %%
df['Gpu_brand'] = df['Gpu'].apply(lambda x:x.split()[0])
df['Gpu_Type'] = df['Gpu'].apply(lambda x:' '.join(x.split()[1:]))
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#       Ram               Memory                           Gpu       OpSys  \
# 0       8            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1       8  128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2       8            256GB SSD         Intel HD Graphics 620       No OS
# 3      16            512GB SSD            AMD Radeon Pro 455       macOS
# 4       8            256GB SSD  Intel Iris Plus Graphics 650       macOS
# ...   ...                  ...                           ...         ...
# 1298    4            128GB SSD         Intel HD Graphics 520  Windows 10
# 1299   16            512GB SSD         Intel HD Graphics 520  Windows 10
# 1300    2   64GB Flash Storage             Intel HD Graphics  Windows 10
# 1301    6              1TB HDD            AMD Radeon R5 M330  Windows 10
# 1302    4            500GB HDD             Intel HD Graphics  Windows 10
#
#       Weight      Price Cpu_Name     Cpu_model Cpu_Speed  Touchscreen  IPS  \
# 0       1.37  108514.89    Intel       Core i5       2.3            0    1
# 1       1.34   72814.14    Intel       Core i5       1.8            0    0
# 2       1.86   46575.00    Intel       Core i5       2.5            0    0
# 3       1.83  205533.45    Intel       Core i7       2.7            0    1
# 4       1.37  146091.60    Intel       Core i5       3.1            0    1
# ...      ...        ...      ...           ...       ...          ...  ...
# 1298    1.80   51678.00    Intel       Core i7       2.5            1    1
# 1299    1.30  121419.00    Intel       Core i7       2.5            1    1
# 1300    1.50   18549.00    Intel  Celeron Dual       1.6            0    0
# 1301    2.19   61884.00    Intel       Core i7       2.5            0    0
# 1302    2.20   29889.00    Intel  Celeron Dual       1.6            0    0
#
#      Resolution Gpu_brand                Gpu_Type
# 0     2560x1600     Intel  Iris Plus Graphics 640
# 1      1440x900     Intel        HD Graphics 6000
# 2     1920x1080     Intel         HD Graphics 620
# 3     2880x1800       AMD          Radeon Pro 455
# 4     2560x1600     Intel  Iris Plus Graphics 650
# ...         ...       ...                     ...
# 1298  1920x1080     Intel         HD Graphics 520
# 1299  3200x1800     Intel         HD Graphics 520
# 1300   1366x768     Intel             HD Graphics
# 1301   1366x768       AMD          Radeon R5 M330
# 1302   1366x768     Intel             HD Graphics
#
# [1303 rows x 18 columns]

# %%
df.drop(columns='Gpu',inplace=True)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#       Ram               Memory       OpSys  Weight      Price Cpu_Name  \
# 0       8            128GB SSD       macOS    1.37  108514.89    Intel
# 1       8  128GB Flash Storage       macOS    1.34   72814.14    Intel
# 2       8            256GB SSD       No OS    1.86   46575.00    Intel
# 3      16            512GB SSD       macOS    1.83  205533.45    Intel
# 4       8            256GB SSD       macOS    1.37  146091.60    Intel
# ...   ...                  ...         ...     ...        ...      ...
# 1298    4            128GB SSD  Windows 10    1.80   51678.00    Intel
# 1299   16            512GB SSD  Windows 10    1.30  121419.00    Intel
# 1300    2   64GB Flash Storage  Windows 10    1.50   18549.00    Intel
# 1301    6              1TB HDD  Windows 10    2.19   61884.00    Intel
# 1302    4            500GB HDD  Windows 10    2.20   29889.00    Intel
#
#          Cpu_model Cpu_Speed  Touchscreen  IPS Resolution Gpu_brand  \
# 0          Core i5       2.3            0    1  2560x1600     Intel
# 1          Core i5       1.8            0    0   1440x900     Intel
# 2          Core i5       2.5            0    0  1920x1080     Intel
# 3          Core i7       2.7            0    1  2880x1800       AMD
# 4          Core i5       3.1            0    1  2560x1600     Intel
# ...            ...       ...          ...  ...        ...       ...
# 1298       Core i7       2.5            1    1  1920x1080     Intel
# 1299       Core i7       2.5            1    1  3200x1800     Intel
# 1300  Celeron Dual       1.6            0    0   1366x768     Intel
# 1301       Core i7       2.5            0    0   1366x768       AMD
# 1302  Celeron Dual       1.6            0    0   1366x768     Intel
#
#                     Gpu_Type
# 0     Iris Plus Graphics 640
# 1           HD Graphics 6000
# 2            HD Graphics 620
# 3             Radeon Pro 455
# 4     Iris Plus Graphics 650
# ...                      ...
# 1298         HD Graphics 520
# 1299         HD Graphics 520
# 1300             HD Graphics
# 1301          Radeon R5 M330
# 1302             HD Graphics
#
# [1303 rows x 17 columns]

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.drop(columns='OpSys',inplace=True)
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#       Ram               Memory  Weight      Price Cpu_Name     Cpu_model  \
# 0       8            128GB SSD    1.37  108514.89    Intel       Core i5
# 1       8  128GB Flash Storage    1.34   72814.14    Intel       Core i5
# 2       8            256GB SSD    1.86   46575.00    Intel       Core i5
# 3      16            512GB SSD    1.83  205533.45    Intel       Core i7
# 4       8            256GB SSD    1.37  146091.60    Intel       Core i5
# ...   ...                  ...     ...        ...      ...           ...
# 1298    4            128GB SSD    1.80   51678.00    Intel       Core i7
# 1299   16            512GB SSD    1.30  121419.00    Intel       Core i7
# 1300    2   64GB Flash Storage    1.50   18549.00    Intel  Celeron Dual
# 1301    6              1TB HDD    2.19   61884.00    Intel       Core i7
# 1302    4            500GB HDD    2.20   29889.00    Intel  Celeron Dual
#
#      Cpu_Speed  Touchscreen  IPS Resolution Gpu_brand                Gpu_Type  \
# 0          2.3            0    1  2560x1600     Intel  Iris Plus Graphics 640
# 1          1.8            0    0   1440x900     Intel        HD Graphics 6000
# 2          2.5            0    0  1920x1080     Intel         HD Graphics 620
# 3          2.7            0    1  2880x1800       AMD          Radeon Pro 455
# 4          3.1            0    1  2560x1600     Intel  Iris Plus Graphics 650
# ...        ...          ...  ...        ...       ...                     ...
# 1298       2.5            1    1  1920x1080     Intel         HD Graphics 520
# 1299       2.5            1    1  3200x1800     Intel         HD Graphics 520
# 1300       1.6            0    0   1366x768     Intel             HD Graphics
# 1301       2.5            0    0   1366x768       AMD          Radeon R5 M330
# 1302       1.6            0    0   1366x768     Intel             HD Graphics
#
#                       os
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# ...                  ...
# 1298             Windows
# 1299             Windows
# 1300             Windows
# 1301             Windows
# 1302             Windows
#
# [1303 rows x 17 columns]

# %%
df['Product'] = df['Product'].str.split("(").apply(lambda x:x[0])

# %%
df['Memory'].unique()
df
# Out:
#      Company             Product            TypeName  Inches  Ram  \
# 0      Apple         MacBook Pro           Ultrabook    13.3    8
# 1      Apple         Macbook Air           Ultrabook    13.3    8
# 2         HP              250 G6            Notebook    15.6    8
# 3      Apple         MacBook Pro           Ultrabook    15.4   16
# 4      Apple         MacBook Pro           Ultrabook    13.3    8
# ...      ...                 ...                 ...     ...  ...
# 1298  Lenovo      Yoga 500-14ISK  2 in 1 Convertible    14.0    4
# 1299  Lenovo      Yoga 900-13ISK  2 in 1 Convertible    13.3   16
# 1300  Lenovo  IdeaPad 100S-14IBR            Notebook    14.0    2
# 1301      HP         15-AC110nv             Notebook    15.6    6
# 1302    Asus      X553SA-XX031T             Notebook    15.6    4
#
#                    Memory  Weight      Price Cpu_Name     Cpu_model Cpu_Speed  \
# 0               128GB SSD    1.37  108514.89    Intel       Core i5       2.3
# 1     128GB Flash Storage    1.34   72814.14    Intel       Core i5       1.8
# 2               256GB SSD    1.86   46575.00    Intel       Core i5       2.5
# 3               512GB SSD    1.83  205533.45    Intel       Core i7       2.7
# 4               256GB SSD    1.37  146091.60    Intel       Core i5       3.1
# ...                   ...     ...        ...      ...           ...       ...
# 1298            128GB SSD    1.80   51678.00    Intel       Core i7       2.5
# 1299            512GB SSD    1.30  121419.00    Intel       Core i7       2.5
# 1300   64GB Flash Storage    1.50   18549.00    Intel  Celeron Dual       1.6
# 1301              1TB HDD    2.19   61884.00    Intel       Core i7       2.5
# 1302            500GB HDD    2.20   29889.00    Intel  Celeron Dual       1.6
#
#       Touchscreen  IPS Resolution Gpu_brand                Gpu_Type  \
# 0               0    1  2560x1600     Intel  Iris Plus Graphics 640
# 1               0    0   1440x900     Intel        HD Graphics 6000
# 2               0    0  1920x1080     Intel         HD Graphics 620
# 3               0    1  2880x1800       AMD          Radeon Pro 455
# 4               0    1  2560x1600     Intel  Iris Plus Graphics 650
# ...           ...  ...        ...       ...                     ...
# 1298            1    1  1920x1080     Intel         HD Graphics 520
# 1299            1    1  3200x1800     Intel         HD Graphics 520
# 1300            0    0   1366x768     Intel             HD Graphics
# 1301            0    0   1366x768       AMD          Radeon R5 M330
# 1302            0    0   1366x768     Intel             HD Graphics
#
#                       os
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# ...                  ...
# 1298             Windows
# 1299             Windows
# 1300             Windows
# 1301             Windows
# 1302             Windows
#
# [1303 rows x 17 columns]

# %%
dfm = df['Memory'].str.split(' ',1,expand=True)
df['Memory_Storage'] = dfm[1]
df['Memory'] = dfm[0]
df
# Out:
#      Company             Product            TypeName  Inches  Ram Memory  \
# 0      Apple         MacBook Pro           Ultrabook    13.3    8  128GB
# 1      Apple         Macbook Air           Ultrabook    13.3    8  128GB
# 2         HP              250 G6            Notebook    15.6    8  256GB
# 3      Apple         MacBook Pro           Ultrabook    15.4   16  512GB
# 4      Apple         MacBook Pro           Ultrabook    13.3    8  256GB
# ...      ...                 ...                 ...     ...  ...    ...
# 1298  Lenovo      Yoga 500-14ISK  2 in 1 Convertible    14.0    4  128GB
# 1299  Lenovo      Yoga 900-13ISK  2 in 1 Convertible    13.3   16  512GB
# 1300  Lenovo  IdeaPad 100S-14IBR            Notebook    14.0    2   64GB
# 1301      HP         15-AC110nv             Notebook    15.6    6    1TB
# 1302    Asus      X553SA-XX031T             Notebook    15.6    4  500GB
#
#       Weight      Price Cpu_Name     Cpu_model Cpu_Speed  Touchscreen  IPS  \
# 0       1.37  108514.89    Intel       Core i5       2.3            0    1
# 1       1.34   72814.14    Intel       Core i5       1.8            0    0
# 2       1.86   46575.00    Intel       Core i5       2.5            0    0
# 3       1.83  205533.45    Intel       Core i7       2.7            0    1
# 4       1.37  146091.60    Intel       Core i5       3.1            0    1
# ...      ...        ...      ...           ...       ...          ...  ...
# 1298    1.80   51678.00    Intel       Core i7       2.5            1    1
# 1299    1.30  121419.00    Intel       Core i7       2.5            1    1
# 1300    1.50   18549.00    Intel  Celeron Dual       1.6            0    0
# 1301    2.19   61884.00    Intel       Core i7       2.5            0    0
# 1302    2.20   29889.00    Intel  Celeron Dual       1.6            0    0
#
#      Resolution Gpu_brand                Gpu_Type                  os  \
# 0     2560x1600     Intel  Iris Plus Graphics 640                 Mac
# 1      1440x900     Intel        HD Graphics 6000                 Mac
# 2     1920x1080     Intel         HD Graphics 620  Others/No OS/Linux
# 3     2880x1800       AMD          Radeon Pro 455                 Mac
# 4     2560x1600     Intel  Iris Plus Graphics 650                 Mac
# ...         ...       ...                     ...                 ...
# 1298  1920x1080     Intel         HD Graphics 520             Windows
# 1299  3200x1800     Intel         HD Graphics 520             Windows
# 1300   1366x768     Intel             HD Graphics             Windows
# 1301   1366x768       AMD          Radeon R5 M330             Windows
# 1302   1366x768     Intel             HD Graphics             Windows
#
#      Memory_Storage
# 0               SSD
# 1     Flash Storage
# 2               SSD
# 3               SSD
# 4               SSD
# ...             ...
# 1298            SSD
# 1299            SSD
# 1300  Flash Storage
# 1301            HDD
# 1302            HDD
#
# [1303 rows x 18 columns]

# %%
df['Memory'].unique()
# Out:
# array(['128GB', '256GB', '512GB', '500GB', '1TB', '32GB', '64GB', '2TB',
#        '1.0TB', '16GB', '180GB', '240GB', '8GB', '508GB'], dtype=object)

# %%
df['Gpu_Type'].unique()
# Out:
# array(['Iris Plus Graphics 640', 'HD Graphics 6000', 'HD Graphics 620',
#        'Radeon Pro 455', 'Iris Plus Graphics 650', 'Radeon R5',
#        'Iris Pro Graphics', 'GeForce MX150', 'UHD Graphics 620',
#        'HD Graphics 520', 'Radeon Pro 555', 'Radeon R5 M430',
#        'HD Graphics 615', 'Radeon Pro 560', 'GeForce 940MX',
#        'HD Graphics 400', 'GeForce GTX 1050', 'Radeon R2', 'Radeon 530',
#        'GeForce 930MX', 'HD Graphics', 'HD Graphics 500',
#        'GeForce GTX 1060', 'GeForce 150MX', 'Iris Graphics 540',
#        'Radeon RX 580', 'GeForce 920MX', 'Radeon R4 Graphics',
#        'Radeon 520', 'GeForce GTX 1070', 'GeForce GTX 1050 Ti',
#        'GeForce MX130', 'R4 Graphics', 'GeForce GTX 940MX',
#        'Radeon RX 560', 'GeForce 920M', 'Radeon R7 M445', 'Radeon RX 550',
#        'GeForce GTX 1050M', 'HD Graphics 515', 'Radeon R5 M420',
#        'HD Graphics 505', 'GTX 980 SLI', 'R17M-M1-70', 'GeForce GTX 1080',
#        'Quadro M1200', 'GeForce GTX 950M', 'FirePro W4190M',
#        'GeForce GTX 980M', 'Iris Graphics 550', 'GeForce 930M',
#        'HD Graphics 630', 'Radeon R5 430', 'GeForce GTX 940M',
#        'HD Graphics 510', 'HD Graphics 405', 'Radeon RX 540',
#        'GeForce GT 940MX', 'FirePro W5130M', 'Quadro M2200M', 'Radeon R4',
#        'Quadro M620', 'Radeon R7 M460', 'HD Graphics 530',
#        'GeForce GTX 965M', 'GeForce GTX1080', 'GeForce GTX1050 Ti',
#        'GeForce GTX 960M', 'Radeon R2 Graphics', 'Quadro M620M',
#        'GeForce GTX 970M', 'GeForce GTX 960<U+039C>', 'Graphics 620',
#        'GeForce GTX 960', 'Radeon R5 520', 'Radeon R7 M440', 'Radeon R7',
#        'Quadro M520M', 'Quadro M2200', 'Quadro M2000M', 'HD Graphics 540',
#        'Quadro M1000M', 'Radeon 540', 'GeForce GTX 1070M',
#        'GeForce GTX1060', 'HD Graphics 5300', 'Radeon R5 M420X',
#        'Radeon R7 Graphics', 'GeForce 920', 'GeForce 940M',
#        'GeForce GTX 930MX', 'Radeon R7 M465', 'Radeon R3',
#        'GeForce GTX 1050Ti', 'Radeon R7 M365X', 'Radeon R9 M385',
#        'Quadro 3000M', 'GeForce GTX 980', 'Radeon R5 M330',
#        'FirePro W6150M', 'Radeon R5 M315', 'Quadro M500M',
#        'Radeon R7 M360', 'Quadro M3000M', 'GeForce 960M', 'Mali T860 MP4'],
#       dtype=object)

# %%
df_mem = df['Memory'].str.split('(\d+)',expand=True)
df['Memory'] = pd.to_numeric(df_mem[1])

df['Memory'] = df['Memory'].apply(lambda x:1024 if x == 1 else x)
df['Memory'] = df['Memory'].apply(lambda x:2048 if x == 2 else x)
df
# Out:
#      Company             Product            TypeName  Inches  Ram  Memory  \
# 0      Apple         MacBook Pro           Ultrabook    13.3    8     128
# 1      Apple         Macbook Air           Ultrabook    13.3    8     128
# 2         HP              250 G6            Notebook    15.6    8     256
# 3      Apple         MacBook Pro           Ultrabook    15.4   16     512
# 4      Apple         MacBook Pro           Ultrabook    13.3    8     256
# ...      ...                 ...                 ...     ...  ...     ...
# 1298  Lenovo      Yoga 500-14ISK  2 in 1 Convertible    14.0    4     128
# 1299  Lenovo      Yoga 900-13ISK  2 in 1 Convertible    13.3   16     512
# 1300  Lenovo  IdeaPad 100S-14IBR            Notebook    14.0    2      64
# 1301      HP         15-AC110nv             Notebook    15.6    6    1024
# 1302    Asus      X553SA-XX031T             Notebook    15.6    4     500
#
#       Weight      Price Cpu_Name     Cpu_model Cpu_Speed  Touchscreen  IPS  \
# 0       1.37  108514.89    Intel       Core i5       2.3            0    1
# 1       1.34   72814.14    Intel       Core i5       1.8            0    0
# 2       1.86   46575.00    Intel       Core i5       2.5            0    0
# 3       1.83  205533.45    Intel       Core i7       2.7            0    1
# 4       1.37  146091.60    Intel       Core i5       3.1            0    1
# ...      ...        ...      ...           ...       ...          ...  ...
# 1298    1.80   51678.00    Intel       Core i7       2.5            1    1
# 1299    1.30  121419.00    Intel       Core i7       2.5            1    1
# 1300    1.50   18549.00    Intel  Celeron Dual       1.6            0    0
# 1301    2.19   61884.00    Intel       Core i7       2.5            0    0
# 1302    2.20   29889.00    Intel  Celeron Dual       1.6            0    0
#
#      Resolution Gpu_brand                Gpu_Type                  os  \
# 0     2560x1600     Intel  Iris Plus Graphics 640                 Mac
# 1      1440x900     Intel        HD Graphics 6000                 Mac
# 2     1920x1080     Intel         HD Graphics 620  Others/No OS/Linux
# 3     2880x1800       AMD          Radeon Pro 455                 Mac
# 4     2560x1600     Intel  Iris Plus Graphics 650                 Mac
# ...         ...       ...                     ...                 ...
# 1298  1920x1080     Intel         HD Graphics 520             Windows
# 1299  3200x1800     Intel         HD Graphics 520             Windows
# 1300   1366x768     Intel             HD Graphics             Windows
# 1301   1366x768       AMD          Radeon R5 M330             Windows
# 1302   1366x768     Intel             HD Graphics             Windows
#
#      Memory_Storage
# 0               SSD
# 1     Flash Storage
# 2               SSD
# 3               SSD
# 4               SSD
# ...             ...
# 1298            SSD
# 1299            SSD
# 1300  Flash Storage
# 1301            HDD
# 1302            HDD
#
# [1303 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'Ram', 'Memory', 'Weight',
#        'Price', 'Cpu_Name', 'Cpu_model', 'Cpu_Speed', 'Touchscreen', 'IPS',
#        'Resolution', 'Gpu_brand', 'Gpu_Type', 'os', 'Memory_Storage'],
#       dtype='object')

# %%
df = df.reindex(columns=['Company', 'TypeName', 'Inches', 'Touchscreen', 'IPS','Cpu_Name', 'Cpu_model', 'Ram', 'Memory', 'Memory_Storage', 'Gpu_brand', 'Gpu_Type',
                        'Weight','os', 'Price'])

# %%
df.rename({'Memory_Storage': 'Memory_Type'},axis=1,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Touchscreen  IPS Cpu_Name Cpu_model  Ram  \
# 0   Apple  Ultrabook    13.3            0    1    Intel   Core i5    8
# 1   Apple  Ultrabook    13.3            0    0    Intel   Core i5    8
# 2      HP   Notebook    15.6            0    0    Intel   Core i5    8
# 3   Apple  Ultrabook    15.4            0    1    Intel   Core i7   16
# 4   Apple  Ultrabook    13.3            0    1    Intel   Core i5    8
#
#    Memory    Memory_Type Gpu_brand                Gpu_Type  Weight  \
# 0     128            SSD     Intel  Iris Plus Graphics 640    1.37
# 1     128  Flash Storage     Intel        HD Graphics 6000    1.34
# 2     256            SSD     Intel         HD Graphics 620    1.86
# 3     512            SSD       AMD          Radeon Pro 455    1.83
# 4     256            SSD     Intel  Iris Plus Graphics 650    1.37
#
#                    os      Price
# 0                 Mac  108514.89
# 1                 Mac   72814.14
# 2  Others/No OS/Linux   46575.00
# 3                 Mac  205533.45
# 4                 Mac  146091.60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Inches       1303 non-null   float64
#  3   Touchscreen  1303 non-null   int64
#  4   IPS          1303 non-null   int64
#  5   Cpu_Name     1303 non-null   object
#  6   Cpu_model    1303 non-null   object
#  7   Ram          1303 non-null   int32
#  8   Memory       1303 non-null   int64
#  9   Memory_Type  1303 non-null   object
#  10  Gpu_brand    1303 non-null   object
#  11  Gpu_Type     1303 non-null   object
#  12  Weight       1303 non-null   float32
#  13  os           1303 non-null   object
#  14  Price        1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), int64(3), object(8)
# memory usage: 142.6+ KB

# %%
backup = df.to_csv("New_Price_Data.csv")

# %%
import seaborn as sns

# %%
sns.set(rc = {'figure.figsize':(10,5)})

# %%
sns.histplot(df['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %% [markdown]
# ## Data Analysis

# %%
df["Company"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df["Company"], y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Company', ylabel='Price'>

# %%
cpu_distribution = df["Cpu_model"].value_counts()[:10].reset_index()
cpu_distribution
# Out:
#               index  Cpu_model
# 0           Core i7        527
# 1           Core i5        423
# 2           Core i3        136
# 3      Celeron Dual         80
# 4      Pentium Quad         27
# 5            Core M         19
# 6    A9-Series 9420         12
# 7      Celeron Quad          8
# 8    A6-Series 9220          8
# 9  A12-Series 9720P          7

# %% [markdown]
# ## Prediction

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X.nunique()
# Out:
# Company         19
# TypeName         6
# Inches          18
# Touchscreen      2
# IPS              2
# Cpu_Name         3
# Cpu_model       40
# Ram              9
# Memory          13
# Memory_Type     12
# Gpu_brand        4
# Gpu_Type       106
# Weight         171
# os               3
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,ExtraTreesRegressor
from xgboost import XGBRegressor

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Touchscreen  IPS Cpu_Name Cpu_model  Ram  \
# 0   Apple  Ultrabook    13.3            0    1    Intel   Core i5    8
# 1   Apple  Ultrabook    13.3            0    0    Intel   Core i5    8
# 2      HP   Notebook    15.6            0    0    Intel   Core i5    8
# 3   Apple  Ultrabook    15.4            0    1    Intel   Core i7   16
# 4   Apple  Ultrabook    13.3            0    1    Intel   Core i5    8
#
#    Memory    Memory_Type Gpu_brand                Gpu_Type  Weight  \
# 0     128            SSD     Intel  Iris Plus Graphics 640    1.37
# 1     128  Flash Storage     Intel        HD Graphics 6000    1.34
# 2     256            SSD     Intel         HD Graphics 620    1.86
# 3     512            SSD       AMD          Radeon Pro 455    1.83
# 4     256            SSD     Intel  Iris Plus Graphics 650    1.37
#
#                    os      Price
# 0                 Mac  108514.89
# 1                 Mac   72814.14
# 2  Others/No OS/Linux   46575.00
# 3                 Mac  205533.45
# 4                 Mac  146091.60

# %%
step1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,1,5,6,9,10,11,13])],
                          remainder='passthrough')
step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)
pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8975659517973994
# MAE 0.15145038275834488
# c:\Users\gaura\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_encoders.py:188: UserWarning: Found unknown categories in columns [3, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
ipe = pickle.load(open("pipe.pkl", "rb"))

# %%
q=np.array(['asus','Notebook',13.3,0,1,'Intel','Core i3',32,500,'sdd','Intel','UHD Graphics 620',1.49,'Window'])

# %%
q=q.reshape(1,14)

# %%
p = str(int(np.exp(ipe.predict(q)[0])))
# Out:
# c:\Users\gaura\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# c:\Users\gaura\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_encoders.py:188: UserWarning: Found unknown categories in columns [0, 4, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
p
# Out:
# '135313'

# %%
type(p)
# Out:
# str
